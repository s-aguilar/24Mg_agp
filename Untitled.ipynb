# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Yields/P1/p1Yields.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0      Run  Detector     Yield  Yield err     Area  Area err  \
# 0            0  run0160  det_h0-0  0.009700   0.000176  6554.49  119.1530
# 1            1  run0160  det_h0-1  0.010436   0.000187  7052.07  126.2520
# 2            2  run0160  det_h0-2  0.004119   0.000126  2783.17   85.0564
# 3            3  run0160  det_h0-3  0.007469   0.000171  5046.87  115.3150
# 4            4  run0160  det_h0-4  0.008349   0.000182  5641.83  123.2300
# 5            5  run0160  det_h0-5  0.009019   0.000215  6094.33  145.1650
# 6            6  run0160  det_h0-6  0.009054   0.000181  6117.73  122.0360
# 7            7  run0160  det_h0-7  0.007112   0.000168  4805.72  113.7960
# 8            8  run0160  det_h1-0  0.007111   0.000167  4804.72  112.6790
# 9            9  run0160  det_h1-1  0.007918   0.000169  5350.16  114.1130
# 10          10  run0160  det_h1-2  0.004251   0.000174  2872.60  117.2630
# 11          11  run0160  det_h1-3  0.009287   0.000241  6275.39  163.1240
# ...

# %%
runs = df.runnum.unique()

# %%
runs
# Out:
# array([160, 161, 162, 167, 172, 173, 174, 175, 176, 177, 178, 179, 180,
#        181, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194,
#        195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207,
#        208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220,
#        221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233,
#        234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 256, 257, 258,
#        259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271,
#        272, 273, 274, 275, 278, 279, 280, 281, 282, 283, 284, 286, 287,
#        288, 291, 292, 293, 295, 296, 297, 298, 299, 300, 301, 302, 303,
#        304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316,
#        317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329,
#        330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342,
#        343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355,
# ...

# %%
topruns = [160,161,162,167,172,260,
           261,262,263,264,265,266,
           267,268,269,270,271,272,
           273,274,275,278]

tempdf = df.query('runnum in @topruns')
group = tempdf.groupby('Detector')['Q_int'].sum()
print(group)
# Out:
# Detector
# det_h0-0    8925578.0
# det_h0-1    8925578.0
# det_h0-2    8925578.0
# det_h0-3    8925578.0
# det_h0-4    8925578.0
# det_h0-5    8925578.0
# det_h0-6    8925578.0
# det_h0-7    8925578.0
# det_h1-0    8925578.0
# det_h1-1    8925578.0
# det_h1-2    8925578.0
# det_h1-3    8925578.0
# det_h1-4    8925578.0
# Name: Q_int, dtype: float64

# %%
# group = df.groupby(['Detector','Q_int']).agg({'sum'})
group = df.groupby('Detector')['Q_int'].sum()
print(group)
# q2 = 1
# print(q2)
# Out:
# Detector
# det_h0-0    55601009.0
# det_h0-1    55601009.0
# det_h0-2    55601009.0
# det_h0-3    55601009.0
# det_h0-4    55601009.0
# det_h0-5    55601009.0
# det_h0-6    55601009.0
# det_h0-7    55601009.0
# det_h1-0    55601009.0
# det_h1-1    55601009.0
# det_h1-2    55601009.0
# det_h1-3    55601009.0
# det_h1-4    55601009.0
# Name: Q_int, dtype: float64
